# %%
BRONZE_PATH = "abfss://yanquiel@dlspl21databricks.dfs.core.windows.net/bronze/orders/"

spark.sql(f"""
CREATE TABLE IF NOT EXISTS dbr_dev.yanquiel_bronze.bronze_orders
USING DELTA
LOCATION '{BRONZE_PATH}'
""")
